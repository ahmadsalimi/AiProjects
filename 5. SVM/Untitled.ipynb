# %%
import numpy as np
import pandas as pd
from pathlib import Path
import PIL
import glob
from matplotlib import image
import matplotlib.pyplot as plt

# %%
classes = Path("PersianLPR/").glob('*')

# %%
X = []
y = []

# %%
for class_path in classes:
    for image_path in class_path.glob("*"):
        image_file = image.imread(image_path)
        y.append('س' if class_path.name == "S" else 'ص' if class_path.name == "W" else class_path.name)
        X.append(image_file.reshape(image_file.size))
X = np.array(X)
y = np.array(y)

# %%
X.shape
# Out:
# (1500, 256)

# %%
y.shape
# Out:
# (1500,)

# %%
columns = {f'pixel{i}': X[:, i] for i in range(y.size}
columns
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-74-929215445692> in <module>
# ----> 1 columns = {f'pixel{i}': X[:, i] for i in range(y.size())}
#       2 columns
#
# TypeError: 'int' object is not callable

# %%
df = pd.DataFrame({'target': y, **{f'pixel{i}': X[:, i] for i in range(X.shape[1])}})
df.head()
# Out:
#   target  pixel0  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  \
# 0      2      86      89      86      80      80      83      80      74
# 1      2     109     117     124     136     141     138     129     121
# 2      2      84      84      90      93      90      81      72      84
# 3      2      69      72      75      73      69      64      61      61
# 4      2      78      81      75      70      61      49      38      26
#
#    pixel8  ...  pixel246  pixel247  pixel248  pixel249  pixel250  pixel251  \
# 0      77  ...       100       109        97        77        63        52
# 1     110  ...        75        82        75        58        34        22
# 2      96  ...        90        84        75        61        52        52
# 3      61  ...       109       116       116       114       111       105
# 4      26  ...       113       119       116       107        99        87
#
#    pixel252  pixel253  pixel254  pixel255
# ...

# %%
df.shape
# Out:
# (1500, 257)

# %%
df.to_csv('PersianLPR.csv', index=False)

# %%
df[df.target == 'ص'].head()
# Out:
#      target  pixel0  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  \
# 1200      ص      51      45      38      26      22      35      57      70
# 1201      ص      27      24      15      12      15      20      26      30
# 1202      ص      60      56      56      63      61      65      82      91
# 1203      ص       0       0       2       5       5       7      16      35
# 1204      ص      16      13      11      11      16      16      19      32
#
#       pixel8  ...  pixel246  pixel247  pixel248  pixel249  pixel250  pixel251  \
# 1200      61  ...       105        45        16        13        16        26
# 1201      29  ...        56        15         2         0         0         0
# 1202      71  ...        86        48        37        45        48        48
# 1203      40  ...        83        35         7         0         0         0
# 1204      30  ...       118        43        13         5         5         5
#
# ...

# %%
data = pd.read_csv('PersianLPR.csv')
data.head()
# Out:
#   target  pixel0  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  \
# 0      2      86      89      86      80      80      83      80      74
# 1      2     109     117     124     136     141     138     129     121
# 2      2      84      84      90      93      90      81      72      84
# 3      2      69      72      75      73      69      64      61      61
# 4      2      78      81      75      70      61      49      38      26
#
#    pixel8  ...  pixel246  pixel247  pixel248  pixel249  pixel250  pixel251  \
# 0      77  ...       100       109        97        77        63        52
# 1     110  ...        75        82        75        58        34        22
# 2      96  ...        90        84        75        61        52        52
# 3      61  ...       109       116       116       114       111       105
# 4      26  ...       113       119       116       107        99        87
#
#    pixel252  pixel253  pixel254  pixel255
# ...

# %%
from sklearn.utils import shuffle

# %%
df = shuffle(df)

# %%
df.head()
# Out:
#      target  pixel0  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  \
# 287       2      69      80      90      92      84      69      57      49
# 165       2      78      92     120     135      92      50       0      28
# 832       7      45      45      62      69      50      25      12       7
# 327       3     117     120     123     122     118     117     117     120
# 1326      ص      19      17      10      17      29      24      29      36
#
#       pixel8  ...  pixel246  pixel247  pixel248  pixel249  pixel250  pixel251  \
# 287       47  ...       139       135       116        86        55        39
# 165       71  ...        78        85        85        78        64        57
# 832        5  ...        69        79        84        79        62        52
# 327      118  ...        90        72        33         5         0         2
# 1326      27  ...        80        49        27        22        15        17
#
# ...
